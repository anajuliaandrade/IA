# %% [markdown]
# ## Teoria da Busca - RPG Game (Cega e Heuristica)

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque
import heapq

#Criar os grafos
G_game = nx.Graph()

# Criar o mapa
locais = {
    'Castelo do heroi': (50, 400),
    'Vila dos Elfos': (110, 450),
    'Floresta dos desafios': (100, 300),
    'Glassard Cay': (20, 250),
    'Stamkasing Isle': (175, 500),
    'Bonafail Cay': (250, 200),
    'Belllams Holm': (100, 50),
    'Walllants Reef': (175, 430),
    'Depar Holm': (300, 500),
    'Flemdwell Key': (275, 325),
    'Caminho da Bruxa': (375, 200),
    'Caverna da Bruxa': (500, 450),
}

# Conexões entre os nós (Arestas)
G_game.add_edge('Castelo do heroi', 'Vila dos Elfos', weight=10)
G_game.add_edge('Castelo do heroi', 'Floresta dos desafios', weight=7)
G_game.add_edge('Vila dos Elfos', 'Glassard Cay', weight=20)
G_game.add_edge('Floresta dos desafios', 'Glassard Cay', weight=25)
G_game.add_edge('Floresta dos desafios', 'Stamkasing Isle', weight=12)
G_game.add_edge('Stamkasing Isle', 'Bonafail Cay', weight=17)
G_game.add_edge('Stamkasing Isle', 'Vila dos Elfos', weight=35)
G_game.add_edge('Glassard Cay', 'Belllams Holm', weight=16)
G_game.add_edge('Belllams Holm', 'Walllants Reef', weight=20)
G_game.add_edge('Belllams Holm', 'Depar Holm', weight=10)
G_game.add_edge('Walllants Reef', 'Depar Holm', weight=15)
G_game.add_edge('Depar Holm', 'Flemdwell Key', weight=10)
G_game.add_edge('Flemdwell Key', 'Caminho da Bruxa', weight=15)
G_game.add_edge('Caminho da Bruxa', 'Caverna da Bruxa', weight=20)
G_game.add_edge('Bonafail Cay','Caverna da Bruxa', weight=40)
G_game.add_edge('Bonafail Cay','Flemdwell Key', weight=20)
G_game.add_edge('Flemdwell Key','Caverna da Bruxa', weight=15)

# Adicionando as posições nos eixos X e Y
for local, pos in locais.items():
    G_game.nodes[local]['pos'] = pos


# Função Plot Mapa
def plot_mapa(grafo, caminho_encontrado, titulo='Mapa do reino'):
    pos = nx.get_node_attributes(grafo, 'pos')
    pesos = nx.get_edge_attributes(grafo, 'weight')

    plt.figure(figsize=(15, 10))

    nx.draw(grafo, pos,
            with_labels=True,
            node_size=1000,
            node_color='lightgray',
            font_size=10,
            font_weight='bold',
            labels={node: node.replace(' ', '\n') for node in grafo.nodes()},
            bbox=dict(
                facecolor='lightblue',
                alpha=0.5,
                edgecolor='none',
                boxstyle='round,pad=0.2'
            ))
    nx.draw_networkx_edge_labels(grafo, pos, edge_labels=pesos, font_size=8, label_pos=0.5)

    if caminho_encontrado:
        caminho_arestas = list(zip(caminho_encontrado, caminho_encontrado[1:]))

        nx.draw_networkx_nodes(grafo, pos, nodelist=caminho_encontrado, node_color='red', node_size=500)
        nx.draw_networkx_edges(grafo, pos, edgelist=caminho_arestas, edge_color='red', node_size=500, width=3)

        nx.draw_networkx_nodes(grafo, pos, nodelist=[caminho_encontrado[0]], node_color='green', node_size=500, label="Inicio")
        nx.draw_networkx_nodes(grafo, pos, nodelist=[caminho_encontrado[-1]], node_color='purple', node_size=500, label="Objetivo")



        plt.text(pos[caminho_encontrado[0]][0], pos[caminho_encontrado[0]][1] + 30, 'Inicio', fontsize=12, ha='center', va='center', color='green')
        plt.text(pos[caminho_encontrado[-1]][0], pos[caminho_encontrado[-1]][1] + 30, 'Objetivo', fontsize=12, ha='center', va='center', color='purple')

    print('teste')
    plt.title(titulo)
    plt.axis('off')
    plt.show()

plot_mapa(G_game, [], titulo='Mapa do Reino - O inicio')
# Out:
# teste

# %% [markdown]
# Busca em Largura (BFS)

# %%
def bfs_game(grafo, inicio, objetivo):
    visitados = set()
    fila = deque([(inicio, [inicio], 0)])

    if inicio == objetivo:
        return [inicio], 0

    while fila:
        no_atual, caminho, custo_total = fila.popleft()

        if no_atual == objetivo:
            return caminho, custo_total

        if no_atual not in visitados:
            visitados.add(no_atual)
            for vizinho in grafo[no_atual]:
                if vizinho not in visitados:
                    novo_custo = custo_total + grafo[no_atual][vizinho]['weight']
                    novo_caminho = list(caminho)
                    novo_caminho.append(vizinho)
                    fila.append((vizinho, novo_caminho, novo_custo))
    return None

# %%
inicio_heroi = "Castelo do heroi"
objetivo_heroi = "Caverna da Bruxa"

caminho_bfs, custo_bfs = bfs_game(G_game, inicio_heroi, objetivo_heroi)

if caminho_bfs:
    print(f"Caminho encontrado: {' -> '.join(caminho_bfs)}")
    print(f"Custo total: {custo_bfs}")
    plot_mapa(G_game, caminho_bfs, titulo='Mapa do Reino - BFS')
else:
    print("Deu errdo!")
# Out:
# Caminho encontrado: Castelo do heroi -> Vila dos Elfos -> Stamkasing Isle -> Bonafail Cay -> Caverna da Bruxa
# Custo total: 102
# teste

# %% [markdown]
# Busca em profundidade (DFS)

# %%
def dfs_game(grafo, inicio, objetivo):
    visitados = set()
    pilha = ([(inicio, [inicio], 0)])

    while pilha:
        no_atual, caminho, custo_total = pilha.pop()

        if no_atual == objetivo:
            return caminho, custo_total

        if no_atual not in visitados:
            visitados.add(no_atual)
            for vizinho in grafo[no_atual]:
                if vizinho not in visitados:
                    novo_custo = custo_total + grafo[no_atual][vizinho]['weight']
                    novo_caminho = list(caminho)
                    novo_caminho.append(vizinho)
                    pilha.append((vizinho, novo_caminho, novo_custo))
    return None

# %%
inicio_heroi = "Castelo do heroi"
objetivo_heroi = "Caverna da Bruxa"

caminho_dfs, custo_dfs = dfs_game(G_game, inicio_heroi, objetivo_heroi)

if caminho_dfs:
    print(f"Caminho encontrado: {' -> '.join(caminho_dfs)}")
    print(f"Custo total: {custo_dfs}")
    plot_mapa(G_game, caminho_dfs, titulo='Mapa do Reino - DFS')
else:
    print("Deu errado!")
# Out:
# Caminho encontrado: Castelo do heroi -> Floresta dos desafios -> Stamkasing Isle -> Vila dos Elfos -> Glassard Cay -> Belllams Holm -> Depar Holm -> Flemdwell Key -> Caverna da Bruxa
# Custo total: 125
# teste

# %% [markdown]
# Busca Gulosa - 1

# %%
# Busca Gulosa
def greedy_bfs_game(grafo, inicio, objetivo, heuristicas):
    """
    Implementa a busca gulosa usando uma heurística para encontrar o caminho.

    Args:
        grafo: Grafo do jogo
        inicio: Nó inicial
        objetivo: Nó objetivo
        heuristicas: Dicionário com valores heurísticos para cada nó

    Returns:
        tuple: (caminho, custo_total) ou None se não encontrar
    """
    visitados = set()
    # Fila de prioridade: (heurística, nó, caminho, custo)
    fila_prioridade = [(heuristicas[inicio], inicio, [inicio], 0)]

    while fila_prioridade:
        # Pega o nó com menor valor heurístico (mais promissor)
        heuristica_atual, no_atual, caminho, custo_total = heapq.heappop(fila_prioridade)

        if no_atual == objetivo:
            return caminho, custo_total

        if no_atual not in visitados:
            visitados.add(no_atual)

            for vizinho in grafo[no_atual]:
                if vizinho not in visitados:
                    # Calcula o custo do caminho atual até o vizinho
                    novo_custo = custo_total + grafo[no_atual][vizinho]['weight']
                    novo_caminho = caminho + [vizinho]

                    # Usa a heurística do vizinho para priorizar
                    heuristica_vizinho = heuristicas[vizinho]

                    heapq.heappush(fila_prioridade,
                                 (heuristica_vizinho, vizinho, novo_caminho, novo_custo))

    return None

# Definindo heurísticas para cada local (distância estimada até a Caverna da Bruxa)
# Valores baseados na posição geográfica aproximada
heuristicas_caverna = {
    'Castelo do heroi': 450,  # Distância estimada do Castelo até a Caverna
    'Vila dos Elfos': 400,
    'Floresta dos desafios': 350,
    'Glassard Cay': 300,
    'Stamkasing Isle': 350,
    'Bonafail Cay': 200,
    'Belllams Holm': 400,
    'Walllants Reef': 300,
    'Depar Holm': 250,
    'Flemdwell Key': 150,
    'Caminho da Bruxa': 50,
    'Caverna da Bruxa': 0  # Objetivo tem heurística 0
}

# Executando a busca gulosa
inicio_heroi = "Castelo do heroi"
objetivo_heroi = "Caverna da Bruxa"

caminho_greedy, custo_greedy = greedy_bfs_game(G_game, inicio_heroi, objetivo_heroi, heuristicas_caverna)

if caminho_greedy:
    print(f"Busca Gulosa - Caminho encontrado: {' -> '.join(caminho_greedy)}")
    print(f"Busca Gulosa - Custo total: {custo_greedy}")
    plot_mapa(G_game, caminho_greedy, titulo='Mapa do Reino - Busca Gulosa')
else:
    print("Busca Gulosa - Caminho não encontrado!")
# Out:
# Busca Gulosa - Caminho encontrado: Castelo do heroi -> Floresta dos desafios -> Stamkasing Isle -> Bonafail Cay -> Caverna da Bruxa
# Busca Gulosa - Custo total: 76
# teste

# %% [markdown]
# Busca Gulosa - 2

# %%
heuristica_game = {
    'Castelo do heroi': 250,
    'Vila dos Elfos': 200,
    'Floresta dos desafios': 10,
    'Glassard Cay': 15,
    'Stamkasing Isle': 600,
    'Bonafail Cay': 400,
    'Belllams Holm': 1012,
    'Walllants Reef': 101,
    'Depar Holm': 156,
    'Flemdwell Key': 10,
    'Caminho da Bruxa': 100,
    'Caverna da Bruxa': 0,
}

# %%
def busca_gulosa_game(grafo, inicio, objetivo, heuristica):
    fronteira = [(heuristica[inicio], [inicio], 0)]
    visitados = set()

    while fronteira:
        _, caminho, custo_total = heapq.heappop(fronteira)
        no_atual = caminho[-1]

        if no_atual == objetivo:
            return caminho, custo_total

        if no_atual not in visitados:
            visitados.add(no_atual)
            for vizinho in grafo[no_atual]:
                if vizinho not in visitados:
                    novo_custo = custo_total + grafo[no_atual][vizinho]['weight']
                    novo_caminho = caminho + [vizinho]
                    heapq.heappush(fronteira, (heuristica[vizinho], novo_caminho, novo_custo))

    return None, 0

# %%
inicio_heroi = "Castelo do heroi"
objetivo_heroi = "Caverna da Bruxa"

caminho_busca_gulosa, custo_busca_gulosa = busca_gulosa_game(G_game, inicio_heroi, objetivo_heroi, heuristica_game)

if caminho_busca_gulosa:
    print(f"Caminho encontrado: {' -> '.join(caminho_busca_gulosa)}")
    print(f"Custo total: {custo_busca_gulosa}")
    plot_mapa(G_game, caminho_busca_gulosa, titulo='Mapa do Reino - Busca Gulosa')
else:
    print("Deu errado!")
# Out:
# Caminho encontrado: Castelo do heroi -> Floresta dos desafios -> Glassard Cay -> Vila dos Elfos -> Stamkasing Isle -> Bonafail Cay -> Caverna da Bruxa
# Custo total: 144
# teste
